# %%
def bubble_sort(arr):
    """
    Bubble Sort Algorithm
    Time Complexity: O(n^2)
    Space Complexity: O(1)
    
    Args:
        arr: List of elements to sort
    
    Returns:
        Sorted list in ascending order
    """
    n = len(arr)
    
    # Traverse through all array elements
    for i in range(n):
        swapped = False
        
        # Last i elements are already in place
        for j in range(0, n - i - 1):
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        
        # If no swaps occurred, array is already sorted
        if not swapped:
            break
    
    return arr


# Test the bubble sort function
test_arr = [64, 34, 25, 12, 22, 11, 90]
print("Original array:", test_arr)
sorted_arr = bubble_sort(test_arr.copy())
print("Sorted array:", sorted_arr)
# Out:
# Original array: [64, 34, 25, 12, 22, 11, 90]
# Sorted array: [11, 12, 22, 25, 34, 64, 90]

# %%
# Insertion Sort

def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        j = i-1
        for x in range(j, -1, -1):
            print("i:", {i}, "j :", {j}, "x :", {x})
            if(arr[x+1] < arr[x]):
                t = arr[x+1]
                arr[x+1] = arr[x]
                arr[x] = t
            else: continue
    
    return arr
             
insertion_sort([11,5,1,13,2,6])
# Out:
# i: {1} j : {0} x : {0}
# i: {2} j : {1} x : {1}
# i: {2} j : {1} x : {0}
# i: {3} j : {2} x : {2}
# i: {3} j : {2} x : {1}
# i: {3} j : {2} x : {0}
# i: {4} j : {3} x : {3}
# i: {4} j : {3} x : {2}
# i: {4} j : {3} x : {1}
# i: {4} j : {3} x : {0}
# i: {5} j : {4} x : {4}
# i: {5} j : {4} x : {3}
# i: {5} j : {4} x : {2}
# i: {5} j : {4} x : {1}
# i: {5} j : {4} x : {0}
# [1, 2, 5, 6, 11, 13]

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
    l = len(arr)
    start = 0
    end = l
    for j in range(l):
        index = find_min(start, end, arr)
        arr[start], arr[index] = arr[index], arr[start]
        start +=1
         
    return arr


def find_min(start, end, arr):
    curr_min = arr[start]
    for i in range(start, end):
        if(arr[i]< curr_min):
            curr_min = arr[i]
    return arr.index(curr_min)
        

test_arr = selection_sort([54, 2, 6, 1, 9, 3, 0, 15])
print("Original Array", test_arr)
# Out:
# Original Array [0, 1, 2, 3, 6, 9, 15, 54]
